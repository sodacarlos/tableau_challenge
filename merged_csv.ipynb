# %%
# Import dependencies
import pandas as pd

# %%
#Import raw csv files
jan_df=pd.read_csv("Raw_CSV/202201-citibike-tripdata.csv", low_memory=False)

# %%
feb_df=pd.read_csv("Raw_CSV/202202-citibike-tripdata.csv", low_memory=False)

# %%
mar_df=pd.read_csv("Raw_CSV/202203-citibike-tripdata.csv", low_memory=False)

# %%
apr_df=pd.read_csv("Raw_CSV/202204-citibike-tripdata.csv", low_memory=False)

# %%
may_df=pd.read_csv("Raw_CSV/202205-citibike-tripdata.csv", low_memory=False)

# %%
jun_df=pd.read_csv("Raw_CSV/202206-citbike-tripdata.csv", low_memory=False)

# %%
#Merging dataframes
merged_csv_df = pd.concat([jan_df, feb_df, mar_df, apr_df, may_df, jun_df])
merged_csv_df
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        55262E4365A955A2   classic_bike  2022-01-18 08:23:52
# 1        D272F1B15D841EC0   classic_bike  2022-01-21 09:03:22
# 2        D1FCEF55EB4A807F   classic_bike  2022-01-22 14:28:32
# 3        E9CBDC6A0162C068  electric_bike  2022-01-19 14:49:47
# 4        2177A5B57326CE9B  electric_bike  2022-01-16 14:36:06
# ...                   ...            ...                  ...
# 3432878  52758C21D58728B4   classic_bike  2022-06-25 00:45:19
# 3432879  2F2B099B77266BF2   classic_bike  2022-06-21 16:52:08
# 3432880  AEE172A41A2FDA65   classic_bike  2022-06-29 17:58:20
# 3432881  3E6A2E15FD49F94E   classic_bike  2022-06-16 19:31:34
# 3432882  EA18E4BF86FD46F8   classic_bike  2022-06-16 12:15:02
#
#                     ended_at        start_station_name start_station_id  \
# 0        2022-01-18 08:28:18   Boerum Pl\t& Pacific St          4488.09
# 1        2022-01-21 09:05:44           E 12 St & Ave C          5616.08
# ...

# %%
# Create a combined csv file.

merged_csv_df.to_csv("cleaned_combined_data.csv", index=False)
